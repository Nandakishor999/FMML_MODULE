# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandakishor999/FMML_MODULE/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-14 16:08:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   128MB/s    in 0.5s
#
# 2025-03-14 16:08:09 (128 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12980   0912.5410v1  Networks are ubiquitous in science and have be...  stat
# 5740    1206.3242v1  Traditional multi-view learning approaches suf...    cs
# 6162   1608.05995v5  We develop an efficient alternating framework ...  stat
# 2630   1702.02519v2  We present Deep Generalized Canonical Correlat...    cs
# 10433   1308.6273v5  In sparse recovery we are given a matrix $A$ (...    cs
# ...             ...                                                ...   ...
# 22261  1510.08110v1  Laplacian Eigenvectors of the graph constructe...  stat
# 29031  1708.02696v1  What is the right way to reason about human ac...    cs
# 5529    1207.0268v1  The problem of bipartite ranking, where instan...    cs
# 10528   1207.1965v1  We consider the setting of sequential predicti...  stat
# 26364  1610.01394v1  We describe an end-to-end framework for learni...    cs
#
#                                                    title  year  \
# 12980             A survey of statistical network models  2009
# 5740   Multi-View Learning in the Presence of View Di...  2012
# 6162   A Non-convex One-Pass Framework for Generalize...  2016
# 2630     Deep Generalized Canonical Correlation Analysis  2017
# 10433  New Algorithms for Learning Incoherent and Ove...  2013
# ...                                                  ...   ...
# 22261       Spectral Convergence Rate of Graph Laplacian  2015
# 29031  What Actions are Needed for Understanding Huma...  2017
# 5529   Surrogate Regret Bounds for Bipartite Ranking ...  2012
# 10528  Forecasting electricity consumption by aggrega...  2012
# 26364  Learning Optimal Parameters for Multi-target T...  2016
#
#                                                 keywords
# 12980  [ubiquitous, discussion, statistical, graphica...
# 5740   [traditional, approaches, disagreementie, corr...
# 6162   [efficient, alternating, framework, generalize...
# 2630   [generalized, canonical, correlation, nonlinea...
# 10433  [processing, statistics, applications, detecti...
# ...                                                  ...
# 22261  [laplacian, eigenvectors, constructed, algorit...
# 29031  [activities, directions, promising, understand...
# 5529   [bipartite, instances, minimizes, probability,...
# 10528  [sequential, prediction, arbitrary, sequences,...
# 26364  [framework, parameters, quadratic, trajectory,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12980    [ubiquitous, discussion, statistical, graphica...
# 5740     [traditional, approaches, disagreementie, corr...
# 6162     [efficient, alternating, framework, generalize...
# 2630     [generalized, canonical, correlation, nonlinea...
# 10433    [processing, statistics, applications, detecti...
#                                ...
# 22704    [misspecified, dynamical, governing, approxima...
# 12463    [exploratory, developing, effective, classific...
# 9677     [introduces, decomposition, systematic, multid...
# 9411     [extension, graphical, fundamental, multivaria...
# 15258    [describes, exclusively, morphological, annota...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8847 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8157bfa-4b3d-4c1b-b045-630efcae1a4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8157bfa-4b3d-4c1b-b045-630efcae1a4f")) {                    Plotly.newPlot(                        "f8157bfa-4b3d-4c1b-b045-630efcae1a4f",                        [{"x":["descriptions","professional","community","communities","ubiquitous","interconnections","emergence","introduce","networking","statistical","estimation","discussion","graphical","historical","representation","prominent","generated","subsequent","specialized","sociology","burgeoning","interpretation","probability","statistics","description","development","substantial","psychology","attention","challenges","literature","empirical","parameters","emphasize","databases","evaluation","detection","criterion","processes","synthetic","successfully","conditional","performance","corruption","demonstrates","traditional","approaches","considerably","disagreement","remaining","filtering","increases","experimental","occlusion","construction","guarantees","algorithm","converges","completion","independent","dimensional","inductive","efficient","symmetric","generalized","conditionally","retrieving","ingredient","framework","operations","coefficient","factorization","retrieval","iteration","alternating","condition","instances","asymmetric","transformations","downstream","maximally","informative","technique","flexibility","recommending","nonlinear","information","measurements","incorporating","arbitrarily","recommendation","formulation","representations","resulting","canonical","stochastic","correlation","optimization","techniques","multiview","articulatory","transcription","resolution","processing","polynomial","algorithms","distribution","allowable","dictionary","applications","dictionaries","incoherent","introduced","particular","previously","complexity","necessary","appropriate","assumptions","compression","polynomially","overcomplete","structure","intractable","thoroughly","exploited","extensions","introduces","approximate","structured","equispaced","preserving","regression","connection","multidimensional","illustrate","observations","directions","covariance","inference","magnitude","including","projection","improving","achieving","functions","backfitting","generally","exploiting","performing","efficiently","dependency","computation","architecture","different","propagation","environment","inferences","probabilities","represent","substantially","disseminate","generalize","correlated","variables","demonstrate","outperform","probabilistic","difficult","benchmarks","outperforming","tractable","typically","decompose","autoregressive","dependencies","computationally","predictive","application","demonstrated","representational","demanding","conditionals","formulations","generalization","classification","smoothing","manifolds","approximations","estimates","complements","implementing","interpolating","differentiation","wasserstein","differentiable","generative","algorithmic","dimension","scenarios"],"y":[33,10,78,32,19,2,17,329,4,182,194,22,48,22,376,20,134,18,27,0,0,52,160,62,73,128,55,8,177,124,113,158,227,11,65,266,362,42,110,132,89,92,865,2,49,169,420,25,5,28,68,38,377,30,82,74,834,21,32,122,179,15,419,27,80,5,13,7,543,76,25,36,98,48,31,52,104,19,42,12,8,38,255,42,3,60,721,51,54,22,31,82,228,176,16,134,75,322,371,8,2,11,132,254,54,609,225,2,59,427,18,6,139,281,83,225,85,58,62,43,4,3,361,26,15,41,43,78,107,119,1,45,126,46,17,70,83,46,23,200,55,221,48,105,89,213,0,67,68,82,180,40,174,257,750,61,114,8,54,95,52,2,58,41,123,572,92,163,149,86,28,29,90,10,5,52,99,66,249,111,7,6,2,18,94,494,15,11,35,72,8,24,3,4,8,34,116,40,55,66],"type":"bar"},{"x":["descriptions","professional","community","comm ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>STDP</span> <span style=''>Based</span> <span style=''>Pruning</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Connections</span> <span style=''>and</span> <span style=''>Weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Quantization</span> <span style=''>in</span> <span style=''>Spiking</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.632183908045977);'>Recognition</span> <br/><br/><span style=''>Spiking</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(SNNs)</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>varied</span> <span style=''>weight</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style=''>in</span> <span style=''>emerging</span> <span style=''>in</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>hardware</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>on</span> <span style=''>crossbar</span> <span style=''>size</span> <span style=''>(implementing</span> <span style=''>dot</span> <span style=''>product)</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conductance</span> <span style=''>levels</span> <span style=''>in</span> <span style=''>non</span> <span style=''>CMOS</span> <span style=''>devices</span> <span style=''>and</span> <span style=''>the</span> <span style=''>power</span> <span style=''>budget</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>SNN</span> <span style=''>topology</span> <span style=''>where</span> <span style=''>non</span> <span style=''>critical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connections</span> <span style=''>are</span> <span style=''>pruned</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>network</span> <span style=''>size</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>remaining</span> <span style=''>critical</span> <span style=''>synapses</span> <span style=''>are</span> <span style=''>weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantized</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>accommodate</span> <span style=''>for</span> <span style=''>limited</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conductance</span> <span style=''>levels</span> <span style=''>Pruning</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>power</span> <span style=''>law</span> <span style=''>weight</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>Spike</span> <span style=''>Timing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>Plasticity</span> <span style=''>(STDP)</span> <span style=''>model</span> <span style=''>synapses</span> <span style=''>between</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style=''>of</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>Errors</span> <span style=''>and</span> <span style=''>Expected</span> <span style=''>Entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distances</span> <br/><br/><span style=''>We</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>value</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Kullback</span> <span style=''>Leibler</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>to</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>priors</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>simplex</span> <span style=''>We</span> <span style=''>obtain</span> <span style=''>closed</span> <span style=''>formulas</span> <span style=''>for</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>errors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>models</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinalities</span> <span style=''>of</span> <span style=''>their</span> <span style=''>sample</span> <span style=''>spaces</span> <span style=''>For</span> <span style=''>the</span> <span style=''>uniform</span> <span style=''>prior</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>from</span> <span style=''>any</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>the</span> <span style=''>uniform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>by</span> <span style=''>a</span> <span style=''>constant</span> <span style=''>1</span> <span style=''>gamma</span> <span style=''>and</span> <span style=''>for</span> <span style=''>the</span> <span style=''>models</span> <span style=''>that</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>this</span> <span style=''>bound</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approached</span> <span style=''>if</span> <span style=''>the</span> <span style=''>state</span> <span style=''>space</span> <span style=''>is</span> <span style=''>very</span> <span style=''>large</span> <span style=''>and</span> <span style=''>the</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>does</span> <span style=''>not</span> <span style=''>grow</span> <span style=''>too</span> <span style=''>fast</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>priors</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>in</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>way</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Sum</span> <span style=''>over</span> <span style=''>Forests</span> <span style=''>density</span> <span style=''>index</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>dense</span> <span style=''>regions</span> <span style=''>in</span> <span style=''>a</span> <span style=''>graph</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857144);'>nonparametric</span> <span style=''>density</span> <span style=''>index</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>the</span> <span style=''>Sum</span> <span style=''>over</span> <span style=''>Forests</span> <span style=''>(SoF)</span> <span style=''>density</span> <span style=''>index</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>clear</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style=''>idea</span> <span style=''>high</span> <span style=''>density</span> <span style=''>regions</span> <span style=''>in</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>they</span> <span style=''>contain</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>low</span> <span style=''>cost</span> <span style=''>trees</span> <span style=''>with</span> <span style=''>high</span> <span style=''>outdegrees</span> <span style=''>while</span> <span style=''>low</span> <span style=''>density</span> <span style=''>regions</span> <span style=''>contain</span> <span style=''>few</span> <span style=''>ones</span> <span style='background-color:rgba(0, 255, 0, 0.3067729083665338);'>Therefore</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Boltzmann</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>countable</span> <span style=''>set</span> <span style=''>of</span> <span style=''>forests</span> <span style=''>in</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>so</span> <span style=''>that</span> <span style=''>large</span> <span style=''>(high</span> <span style=''>cost)</span> <span style=''>forests</span> <span style=''>occur</span> <span style=''>with</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>while</span> <span style=''>short</span> <span style=''>(low</span> <span style=''>cost)</span> <span style=''>forests</span> <span style=''>occur</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>Then</span> <span style=''>the</span> <span style=''>SoF</span> <span style=''>density</span> <span style=''>index</span> <span style=''>of</span> <span style=''>a</span> <span style=''>node</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>outdegree</span> <span style=''>of</span> <span style=''>this</span> <span style=''>node</span> <span style=''>in</span> <span style=''>a</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Narrow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>Machines</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximators</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>deep</span> <span style=''>narrow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activities</span> <span style=''>of</span> <span style=''>their</span> <span style=''>visible</span> <span style=''>units</span> <span style=''>provided</span> <span style=''>they</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>many</span> <span style=''>hidden</span> <span style=''>layers</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>the</span> <span style=''>same</span> <span style=''>number</span> <span style=''>of</span> <span style=''>units</span> <span style=''>as</span> <span style=''>the</span> <span style=''>visible</span> <span style=''>layer</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>within</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>domains</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>can</span> <span style=''>be</span> <span style=''>studied</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>feedforward</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>upper</span> <span style=''>and</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>depth</span> <span style=''>and</span> <span style=''>width</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>These</span> <span style=''>results</span> <span style=''>settle</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>they</span> <span style=''>show</span> <span style=''>that</span> <span style=''>deep</span> <span style=''>narrow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>are</span> <span style=''>at</span> <span style=''>least</span> <span style=''>as</span> <span style=''>compact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>as</span> <span style=''>narrow</span> <span style=''>sigmoid</span> <span style=''>belief</span> <span style=''>networks</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09520400858983537)
# 	experimental (0.13493199713672155)
# 	representation (0.13457408732999285)
# 	architecture (0.09198282032927703)
# 	information (0.2580529706513959)
# 	segmentation (0.0819613457408733)
# 	different (0.2684323550465283)
# 	detection (0.12956335003579098)
# 	recognition (0.12705798138869004)
# 	convolutional (0.14459556191839656)
#
# Some Statistics words are:
# 	distributions (0.12063808574277168)
# 	statistical (0.15204386839481554)
# 	stochastic (0.14007976071784647)
# 	variables (0.14007976071784647)
# 	theoretical (0.1465603190428714)
# 	estimation (0.16999002991026918)
# 	distribution (0.18943170488534397)
# 	inference (0.193419740777667)
# 	dimensional (0.19242273180458624)
# 	regression (0.17497507477567298)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="05f10215-dc90-4b03-9703-2759d57a129f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05f10215-dc90-4b03-9703-2759d57a129f")) {                    Plotly.newPlot(                        "05f10215-dc90-4b03-9703-2759d57a129f",                        [{"x":["descriptions","professional","community","communities","ubiquitous","interconnections","emergence","introduce","networking","statistical","estimation","discussion","graphical","historical","representation","prominent","generated","subsequent","specialized","sociology","burgeoning","interpretation","probability","statistics","description","development","substantial","psychology","attention","challenges","literature","empirical","parameters","emphasize","databases","evaluation","detection","criterion","processes","synthetic","successfully","conditional","performance","corruption","demonstrates","traditional","approaches","considerably","disagreement","remaining","filtering","increases","experimental","occlusion","construction","guarantees","algorithm","converges","completion","independent","dimensional","inductive","efficient","symmetric","generalized","conditionally","retrieving","ingredient","framework","operations","coefficient","factorization","retrieval","iteration","alternating","condition","instances","asymmetric","transformations","downstream","maximally","informative","technique","flexibility","recommending","nonlinear","information","measurements","incorporating","arbitrarily","recommendation","formulation","representations","resulting","canonical","stochastic","correlation","optimization","techniques","multiview","articulatory","transcription","resolution","processing","polynomial","algorithms","distribution","allowable","dictionary","applications","dictionaries","incoherent","introduced","particular","previously","complexity","necessary","appropriate","assumptions","compression","polynomially","overcomplete","structure","intractable","thoroughly","exploited","extensions","introduces","approximate","structured","equispaced","preserving","regression","connection","multidimensional","illustrate","observations","directions","covariance","inference","magnitude","including","projection","improving","achieving","functions","backfitting","generally","exploiting","performing","efficiently","dependency","computation","architecture","different","propagation","environment","inferences","probabilities","represent","substantially","disseminate","generalize","correlated","variables","demonstrate","outperform","probabilistic","difficult","benchmarks","outperforming","tractable","typically","decompose","autoregressive","dependencies","computationally","predictive","application","demonstrated","representational","demanding","conditionals","formulations","generalization","classification","smoothing","manifolds","approximations","estimates","complements","implementing","interpolating","differentiation","wasserstein","differentiable","generative","algorithmic","dimension","scenarios","difficulty","gradients","transport","computational","favorable","streamlined","divergences","execution","generates","smoothness","discrepancy","formidable","alternative","problematic","approximation","degenerate","specifically","instability","iterations","supported","leveraging","unfortunately","distributions","evaluating","competitiveness","identified","differential","measuring","convergence","implemented","benchmark","unconstrained","multimodal","dimensions","evolution","competitive","separable","objective","implicitly","separately","extracted","explicitly","artificial","adaptively","combinations","automatically","classical","considering","reproducing","embeddings","recursive","important","contr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sociology
# 	burgeoning
# 	backfitting
# 	individualized
# 	physiologic
# 	smoothers
# 	tibshirani
# 	hemoglobin
# 	nucleotide
# 	obscuring
# 	infectious
# 	reconcile
# 	integrator
# 	formalise
# 	unobservable
# 	astronomical
# 	looseness
# 	disentanglement
# 	confounders
# 	emphmulti
# Some words which never appear in Statistics papers:
# 	articulatory
# 	transcription
# 	allowable
# 	disseminate
# 	troubleshooting
# 	transducer
# 	hyperedges
# 	stylistic
# 	distinctiveness
# 	translators
# 	gazetteers
# 	unannotated
# 	conversational
# 	traverses
# 	immutable
# 	coherency
# 	awareness
# 	activitynet
# 	spectacular
# 	articulated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0745580322828594e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.745
